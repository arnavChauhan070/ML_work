# %%
from google.colab import userdata
api = userdata.get('api')

# %%
from huggingface_hub import login

login(api)

# %%
#  Scenario: AI‑Powered Email Assistant
# You’re building an email drafting assistant for a corporate team.
# - When a user starts typing:
# “Artificial Intelligence will…”
# - The assistant uses GPT‑2 to auto‑complete the sentence with a coherent continuation.
# - Example output:
# “Artificial Intelligence will transform the way businesses interact with customers,
# enabling faster decisions and personalized experiences.”

from transformers import pipeline

generator = pipeline("text-generation", model="gpt2")

print(generator("Artificial Intelligence will", max_length=30))

# %%
prompt = """Scenario: Game Storyline Generator
 You’re designing a fantasy role‑playing game and need quick ideas for quests and dialogue.
  The developer types a prompt:
The hero enters the ancient forest and discovers…
The GPT‑2 pipeline continues the story
The hero enters the ancient forest and discovers a hidden village where the people whisper of
 a cursed artifact buried beneath the old ruins."""

# %%
# Scenario: Research Assistant for Academic Papers
# Imagine you’re building a tool for university researchers who analyze large collections of academic papers.
# - A researcher uploads a sentence:
# “Deep learning models are powerful”
# - Your system uses the BERT tokenizer to break the sentence into smaller units (tokens).

from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")

text = "Deep learning models are powerful"

tokens = tokenizer.tokenize(text)

print(tokens)

# %%
from transformers import BertTokenizer

# load tokenizer
tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")

sentence = """ Scenario: Healthcare Chatbot for Patient Queries

A hospital is developing an AI-powered chatbot to help patients ask questions about their health conditions.
Patients can type symptoms or medical concerns, and the chatbot will analyze the text before providing helpful responses or directing them to a doctor.

To understand the patient’s query, the chatbot first processes the input text using Natural Language Processing (NLP).
The BERT tokenizer is used to break the sentence into smaller tokens (words or sub-words) that the model can understand.

For example, a patient might type:

"I have chest pain and shortness of breath."

The BERT tokenizer converts this sentence into tokens so the machine learning model can process the meaning of the patient's message and generate an appropriate response.
"""


tokens = tokenizer.tokenize(sentence)

print(tokens)
# Out:
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# ['scenario', ':', 'healthcare', 'chat', '##bot', 'for', 'patient', 'que', '##ries', 'a', 'hospital', 'is', 'developing', 'an', 'ai', '-', 'powered', 'chat', '##bot', 'to', 'help', 'patients', 'ask', 'questions', 'about', 'their', 'health', 'conditions', '.', 'patients', 'can', 'type', 'symptoms', 'or', 'medical', 'concerns', ',', 'and', 'the', 'chat', '##bot', 'will', 'analyze', 'the', 'text', 'before', 'providing', 'helpful', 'responses', 'or', 'directing', 'them', 'to', 'a', 'doctor', '.', 'to', 'understand', 'the', 'patient', '’', 's', 'query', ',', 'the', 'chat', '##bot', 'first', 'processes', 'the', 'input', 'text', 'using', 'natural', 'language', 'processing', '(', 'nl', '##p', ')', '.', 'the', 'bert', 'token', '##izer', 'is', 'used', 'to', 'break', 'the', 'sentence', 'into', 'smaller', 'token', '##s', '(', 'words', 'or', 'sub', '-', 'words', ')', 'that', 'the', 'model', 'can', 'understand', '.', 'for', 'example', ',', 'a', 'patient', 'might', 'type', ':', '"', 'i', 'have', 'chest', 'pain', 'and', 'short', '##ness', 'of', 'breath', '.', '"', 'the', 'bert', 'token', '##izer', 'converts', 'this', 'sentence', 'into', 'token', '##s', 'so', 'the', 'machine', 'learning', 'model', 'can', 'process', 'the', 'meaning', 'of', 'the', 'patient', "'", 's', 'message', 'and', 'generate', 'an', 'appropriate', 'response', '.']

# %%
from transformers import pipeline

generator = pipeline("text-generation", model="gpt2")

print(generator(prompt, max_new_tokens = 50))
# Out:
# Loading weights:   0%|          | 0/201 [00:00<?, ?it/s]
# Passing `generation_config` together with generation-related arguments=({'max_new_tokens'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# Both `max_new_tokens` (=50) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': 'Scenario: Game Storyline Generator\n You’re designing a fantasy role‑playing game and need quick ideas for quests and dialogue.\n  The developer types a prompt:\nThe hero enters the ancient forest and discovers…\nThe GPT‑2 pipeline continues the story\nThe hero enters the ancient forest and discovers a hidden village where the people whisper of\n a cursed artifact buried beneath the old ruins. The villagers are afraid to speak of it, but the hero is determined to uncover its secrets.\nThe villagers warn the hero to stay away. The villagers tell the hero of a wicked sorcerer who has been seeking'}]

# %%
# # Scenario: Scriptwriting Assistant for Film Production

# A film studio is experimenting with Artificial Intelligence to help writers brainstorm dialogue and plot ideas.
# The AI system can generate different styles of text depending on the **temperature parameter**, which controls randomness in text generation.

# The writer provides the prompt:

# "The future of Artificial Intelligence"

# The system generates two versions of the continuation:

# **Temperature = 0.2 (Low randomness)**
# The output is more predictable, structured, and factual.
# Example:
# "The future of Artificial Intelligence will improve industries, enhance productivity, and reshape education."

# This type of output is useful for **serious narration in documentaries or educational scripts**.

# **Temperature = 0.8 (High randomness)**
# The output becomes more imaginative and creative.
# Example:
# "The future of Artificial Intelligence dances with uncertainty, weaving stories of machines dreaming and societies reborn."

# This type of output is useful for **creative storytelling, film dialogue, and science-fiction scripts**.

# %%
sentence = """
 Scenario: Scriptwriting Assistant for Film Production

A film studio is experimenting with Artificial Intelligence to help writers brainstorm dialogue and plot ideas.
The AI system can generate different styles of text depending on the **temperature parameter**, which controls randomness in text generation.

The writer provides the prompt:

"The future of Artificial Intelligence"

The system generates two versions of the continuation:

**Temperature = 0.2 (Low randomness)**
The output is more predictable, structured, and factual.
Example:
"The future of Artificial Intelligence will improve industries, enhance productivity, and reshape education."

This type of output is useful for **serious narration in documentaries or educational scripts**.

**Temperature = 0.8 (High randomness)**
The output becomes more imaginative and creative.
Example:
"The future of Artificial Intelligence dances with uncertainty, weaving stories of machines dreaming and societies reborn."

This type of output is useful for **creative storytelling, film dialogue, and science-fiction scripts**.

"""

# %%
from transformers import pipeline

generator = pipeline("text-generation", model="gpt2")

prompt = sentence


low_temp = generator(
    prompt,
    max_new_tokens=30,
    temperature=0.2,
    do_sample=True
)


high_temp = generator(
    prompt,
    max_new_tokens=30,
    temperature=0.8,
    do_sample=True
)

print("Low Temperature Output:")
print(low_temp[0]["generated_text"])

print("\nHigh Temperature Output:")
print(high_temp[0]["generated_text"])
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Passing `generation_config` together with generation-related arguments=({'temperature', 'do_sample', 'max_new_tokens'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=30) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=30) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Low Temperature Output:
#  Scenario: Healthcare Chatbot for Patient Queries
#
# A hospital is developing an AI-powered chatbot to help patients ask questions about their health conditions.
# Patients can type symptoms or medical concerns, and the chatbot will analyze the text before providing helpful responses or directing them to a doctor.
#
# To understand the patient’s query, the chatbot first processes the input text using Natural Language Processing (NLP).
# The BERT tokenizer is used to break the sentence into smaller tokens (words or sub-words) that the model can understand.
#
# For example, a patient might type:
#
# "I have chest pain and shortness of breath."
#
# The BERT tokenizer converts this sentence into tokens so the machine learning model can process the meaning of the patient's message and generate an appropriate response.
#
# The machine learning model can then use the BERT tokenizer to generate a response that is more accurate than the original sentence.
#
# The B
#
# High Temperature Output:
#  Scenario: Healthcare Chatbot for Patient Queries
#
# A hospital is developing an AI-powered chatbot to help patients ask questions about their health conditions.
# Patients can type symptoms or medical concerns, and the chatbot will analyze the text before providing helpful responses or directing them to a doctor.
#
# To understand the patient’s query, the chatbot first processes the input text using Natural Language Processing (NLP).
# The BERT tokenizer is used to break the sentence into smaller tokens (words or sub-words) that the model can understand.
#
# For example, a patient might type:
#
# "I have chest pain and shortness of breath."
#
# The BERT tokenizer converts this sentence into tokens so the machine learning model can process the meaning of the patient's message and generate an appropriate response.
#
# The AI can then analyze the text and analyze the response to understand the patient's questions, the context in which the text was written, and the

# %%
# Scenario: AI‑Powered News Headline Generator
# A digital media company wants to help journalists brainstorm headlines and opening lines for articles.
# - The system asks the journalist to enter a prompt (e.g., “Enter a prompt: The future of Artificial Intelligence”).
# - The GPT‑2 model then generates a continuation of the text, up to 50 tokens.
# - Example output:
# “The future of Artificial Intelligence will reshape industries, redefine creativity, and challenge
#  our understanding of human potential.”

from transformers import pipeline

generator = pipeline("text-generation", model="gpt2")

prompt = input("Enter a prompt: ")

output = generator(prompt, max_new_tokens=50)

print(output[0]["generated_text"])
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Enter a prompt: Ai advancements in Future
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=50) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Ai advancements in Future-Tuned Computing: A Comparison of Parallel and Parallel Processing
#
# The future of computing is finally coming to a close. Today, IBM is releasing the Future-Tuned Computing (FTP) standard today for the first time in its "next

# %%
# 🎓 Scenario: Student Brainstorming Tool for Essay Writing
# A college student is struggling to start their essay.
# - The system prompts them:
# “Enter a prompt:”
# - The student types:
# “The impact of technology on education”
# - The GPT‑2 model generates a continuation up to 50 tokens, for example:
# “The impact of technology on education has transformed classrooms, enabling online learning,
# personalized study plans, and global collaboration among students.”

# %%
from transformers import pipeline

generator = pipeline("text-generation", model="gpt2")

prompt = input("Enter a prompt: ")

output = generator(prompt, max_new_tokens=50)

print(output[0]["generated_text"])
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Enter a prompt: Features of MacBook Neo
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=50) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Features of MacBook Neo 6.0 and MacBook Pro 6.0 (Note: The MacBook Pro 6.0 was a little earlier than the MacBook Pro 6.0)
#
# The MacBook Pro 6.0 (Note: The MacBook Pro 6.0 and Mac

# %%
# Scenario: AI Model Evaluation in a Startup
# A startup is building an AI‑powered content assistant to help marketers draft product descriptions.
# - The team wants to compare two models: GPT‑2 (larger, more expressive) and DistilGPT‑2 (smaller, faster, distilled version).
# - They use the same prompt:
# “Artificial Intelligence will transform”
# - The system generates two outputs:
# - GPT‑2 Output
# Longer, more detailed continuation, e.g.:
# “Artificial Intelligence will transform industries by automating processes, enhancing creativity, and
# reshaping how humans interact with technology.”
# → Richer but slower to run.
# - DistilGPT‑2 Output


from transformers import pipeline

gpt2 = pipeline("text-generation", model="gpt2-large")
distilgpt2 = pipeline("text-generation", model="distilgpt2")

prompt = "Artificial Intelligence will transform"

print("GPT2:", gpt2(prompt, max_length=40))
print("DistilGPT2:", distilgpt2(prompt, max_length=40))
# Out:
# config.json:   0%|          | 0.00/666 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/3.25G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/436 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2-large
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...35}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# config.json:   0%|          | 0.00/762 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/353M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/76 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: distilgpt2
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# transformer.h.{0, 1, 2, 3, 4, 5}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# GPT2: [{'generated_text': "Artificial Intelligence will transform society, the first and foremost goal is to control it. As a society we must realize that AI is not about human capability, but about human control of AI.\n\nThe second goal is to control AI through controlling the human's ability to control it. This will be achieved by creating AI that is self-aware, that uses its intelligence to determine what is best for it, and to control what happens to it.\n\nThe third goal is to create AI that is aware of its own existence and its own self-awareness. This will be achieved by creating AI that can be aware of its own existence and self-awareness.\n\nThe fourth goal is to create AI that is self-aware of its own existence and self-awareness. This will be achieved by creating AI that is self-aware of its own existence and self-awareness.\n\nThe fifth goal is to create AI that is self-aware of its own existence and self-awareness. This will be achieved by creating AI that is self-aware of its existence and self-awareness.\n\nThe sixth goal is to create AI that is self-aware of its own existence and self-awareness. This will be achieved by creating AI that is self-aware of its own existence and self"}]
# DistilGPT2: [{'generated_text': 'Artificial Intelligence will transform the way the world is viewed and understood, and the future of humanity will be shaped by it.\n\n\n\n\nWe look forward to hearing from you.\n-'}]

# %%
# Scenario: Educational Tool for Classroom Learning
# A high school teacher is introducing students to AI‑powered writing assistants.
# - The teacher wants to show how different models produce different styles of text.
# - They use the same prompt:
# “Artificial Intelligence will transform”
# - The system generates two outputs:
# - GPT‑2 Output
# More elaborate continuation, e.g.:
# “Artificial Intelligence will transform the way societies function, influencing education, healthcare, and the future of human creativity.”
# → Great for showing students how AI can generate rich, detailed ideas.
# - DistilGPT‑2 Output
# Shorter, faster continuation, e.g.:
# “Artificial Intelligence will transform our daily lives.”
# → Useful for demonstrating concise summaries.

# %%
from transformers import pipeline

prompt = "Artificial Intelligence will transform"

# GPT-2 model
gpt2 = pipeline("text-generation", model="gpt2")
gpt2_output = gpt2(prompt, max_new_tokens=30)

# DistilGPT-2 model
distilgpt2 = pipeline("text-generation", model="distilgpt2")
distil_output = distilgpt2(prompt, max_new_tokens=30)

print("GPT-2 Output:")
print(gpt2_output[0]["generated_text"])

print("\nDistilGPT-2 Output:")
print(distil_output[0]["generated_text"])
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=30) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Loading weights:   0%|          | 0/76 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: distilgpt2
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# transformer.h.{0, 1, 2, 3, 4, 5}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=30) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# GPT-2 Output:
# Artificial Intelligence will transform social media and other technology to create an ecosystem where people can interact directly with one another and share information freely, with no limitations.
#
# The company
#
# DistilGPT-2 Output:
# Artificial Intelligence will transform the way we work and our jobs.
