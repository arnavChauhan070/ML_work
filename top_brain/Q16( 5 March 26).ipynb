# %%
# Scenario:
# We want to classify whether a restaurant order is “Large” (1) or “Small” (0) based on the number
#  of items ordered.
# - If items ≥ 3 → Large order
# - If items < 3 → Small order

# %%
import numpy as np

X = np.array([[2], [3], [6], [8]])   # input: item size
y = np.array([0, 0, 1, 1])   # greater than 3 Large order else small


weights = np.random.rand(1)   # single input → single weight
bias = np.random.rand(1)
learning_rate = 0.1

# Step 3: Activation Function (Step function)
def activation(z):
    return 1 if z >= 0 else 0

# Step 4: Training Loop
for epoch in range(10):  # run for 10 iterations
    print(f"Epoch {epoch+1}")
    for i in range(len(X)):
        # Linear combination
        z = np.dot(X[i], weights) + bias
        y_pred = activation(z)

        # Error
        error = y[i] - y_pred

        # Update rule
        weights += learning_rate * error * X[i]
        bias += learning_rate * error

        print(f"Input: {X[i]}, Predicted: {y_pred}, Actual: {y[i]}, Error: {error}")

print("\nFinal Weights:", weights)
print("Final Bias:", bias)

# Step 5: Test the perceptron
test_items = np.array([2, 7])
for h in test_items:
    z = np.dot(h, weights) + bias
    print(f"Item Size : {h}, Prediction: {activation(z)}")
    print("Small Order" if activation(z) == 0 else "Large Order")
# Out:
# Epoch 1
# Input: [2], Predicted: 1, Actual: 0, Error: -1
# Input: [3], Predicted: 1, Actual: 0, Error: -1
# Input: [6], Predicted: 0, Actual: 1, Error: 1
# Input: [8], Predicted: 1, Actual: 1, Error: 0
# Epoch 2
# Input: [2], Predicted: 1, Actual: 0, Error: -1
# Input: [3], Predicted: 1, Actual: 0, Error: -1
# Input: [6], Predicted: 0, Actual: 1, Error: 1
# Input: [8], Predicted: 1, Actual: 1, Error: 0
# Epoch 3
# Input: [2], Predicted: 1, Actual: 0, Error: -1
# Input: [3], Predicted: 1, Actual: 0, Error: -1
# Input: [6], Predicted: 0, Actual: 1, Error: 1
# Input: [8], Predicted: 1, Actual: 1, Error: 0
# Epoch 4
# Input: [2], Predicted: 1, Actual: 0, Error: -1
# Input: [3], Predicted: 1, Actual: 0, Error: -1
# Input: [6], Predicted: 1, Actual: 1, Error: 0
# Input: [8], Predicted: 0, Actual: 1, Error: 1
# Epoch 5
# Input: [2], Predicted: 1, Actual: 0, Error: -1
# Input: [3], Predicted: 1, Actual: 0, Error: -1
# Input: [6], Predicted: 1, Actual: 1, Error: 0
# Input: [8], Predicted: 1, Actual: 1, Error: 0
# Epoch 6
# Input: [2], Predicted: 1, Actual: 0, Error: -1
# Input: [3], Predicted: 1, Actual: 0, Error: -1
# Input: [6], Predicted: 0, Actual: 1, Error: 1
# Input: [8], Predicted: 1, Actual: 1, Error: 0
# Epoch 7
# Input: [2], Predicted: 1, Actual: 0, Error: -1
# Input: [3], Predicted: 1, Actual: 0, Error: -1
# Input: [6], Predicted: 0, Actual: 1, Error: 1
# Input: [8], Predicted: 1, Actual: 1, Error: 0
# Epoch 8
# Input: [2], Predicted: 1, Actual: 0, Error: -1
# Input: [3], Predicted: 1, Actual: 0, Error: -1
# Input: [6], Predicted: 0, Actual: 1, Error: 1
# Input: [8], Predicted: 1, Actual: 1, Error: 0
# Epoch 9
# Input: [2], Predicted: 1, Actual: 0, Error: -1
# Input: [3], Predicted: 1, Actual: 0, Error: -1
# Input: [6], Predicted: 1, Actual: 1, Error: 0
# Input: [8], Predicted: 1, Actual: 1, Error: 0
# Epoch 10
# Input: [2], Predicted: 0, Actual: 0, Error: 0
# Input: [3], Predicted: 0, Actual: 0, Error: 0
# Input: [6], Predicted: 1, Actual: 1, Error: 0
# Input: [8], Predicted: 1, Actual: 1, Error: 0
#
# Final Weights: [0.04872317]
# Final Bias: [-0.28326478]
# Item Size : 2, Prediction: 0
# Small Order
# Item Size : 7, Prediction: 1
# Large Order
